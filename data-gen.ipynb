# %%
import bbc

# %%
news = bbc.news.get_news(bbc.Languages.English)

# %%
news.raw_response
# Out:
# {'Latest': [{'title': 'Within seconds, celebrations turn to mayhem and tragedy in New Orleans',
#    'summary': "The beating heart of New Orleans' vibrant nightlife became a scene of carnage when a van plowed into crowds.",
#    'image_link': 'https://ichef.bbci.co.uk/news/240/cpsprodpb/8efb/live/f5c4b850-c90e-11ef-87df-d575b9a434a4.jpg.webp',
#    'news_link': 'https://bbc.com/news/articles/cdjg0r2p49xo'},
#   {'title': 'People run to escape New Orleans truck attack',
#    'summary': "CCTV footage shows people leaping out of the way of the vehicle, as it was driven at crowds on New Year's Day.",
#    'image_link': 'https://ichef.bbci.co.uk/news/240/cpsprodpb/8dcd/live/c8342050-c90a-11ef-94cb-5f844ceb9e30.jpg.webp',
#    'news_link': 'https://bbc.com/news/videos/cn4xnv42l84o'},
#   {'title': 'Within seconds, celebrations turn to mayhem and tragedy in New Orleans',
# ...
